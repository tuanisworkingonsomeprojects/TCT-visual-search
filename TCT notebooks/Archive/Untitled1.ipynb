# %%
import matplotlib.pyplot as plt

# %%
import pickle

# %%
with open(os.path.join(root_folder, 'TCT-visual-search/results/NGTU1[coco18]performance.pkl'), 'rb') as handle:
    pickle.dump(TCT_coco_performance, handle, protocol=pickle.HIGHEST_PROTOCOL)
